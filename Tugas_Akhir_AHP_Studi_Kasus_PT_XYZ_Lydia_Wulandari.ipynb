# %% [markdown]
# <a href="https://colab.research.google.com/github/LydiaWulandari/1/blob/main/Tugas_Akhir_AHP_Studi_Kasus_PT_XYZ_Lydia_Wulandari.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # AHP DALAM MENENTUKAN PERINGKAT KUALITAS PENJUALAN ALAT PER PERIODE

# %% [markdown]
# ## ALGORITMA

# %%
# Skenario

# Step 1: Perumusan masalah dan tujuan / solusi
#1.1 Rumusan masalah
#1.2 Tujuan / solusi
#1.3 Penentuan kriteria, sub kriteria, dan alternatif

# Step 2: Struktur hierarki
#Menyusun masalah ke dalam struktur hierarki : Level 1 adalah tujuan utama, level 2 adalah kriteria, level 3 adalah sub kriteria, dan level 4 adalah alternatif yang menunjukan keterhubungan elemen satu dengan elemen lainnya. Hasilnya adalah diagram hierarki.

# Step 3: Matriks Perbandingan Berpasangan Terhadap Kriteria (Pairwise Comparison Matrix)
#3.1 Perbandingan berpasangan setiap kriteria
#3.2 Penilaian expert setiap kriteria
#3.3 Tabel matriks perbandingan berpasangan kriteria

# Step 4: Eigen Vektor Normalisasi
#4.1 Normalisasi data matriks kriteria
#4.2 Bobot kriteria
#4.3 Hasil data matriks kriteria

# Step 5: Ulang Tahap 3 dan 4 untuk Setiap Sub Kriteria
#5.1 Sub Kriteria Jumlah_Pelanggan
    #5.1.1 Perbandingan berpasangan sub kriteria Jumlah_Pelanggan
    #5.1.2 Penilaian expert sub kriteria Jumlah_Pelanggan
    #5.1.3 Tabel matriks perbandingan berpasangan sub kriteria Jumlah_Pelanggan
    #5.1.4 Normalisasi data matriks sub kriteria Jumlah_Pelanggan
    #5.1.5 Bobot sub kriteria Jumlah_Pelanggan
    #5.1.6 Grafik Bobot Sub Kriteria Jumlah_Pelanggan
    #5.1.7 Hasil data matriks sub kriteria Jumlah_Pelanggan
#5.2 Sub Kriteria Jumlah_Alat_Masuk
    #5.2.1 Perbandingan berpasangan sub kriteria Jumlah_Alat_Masuk
    #5.2.2 Penilaian expert sub kriteria Jumlah_Alat_Masuk
    #5.2.3 Tabel matriks perbandingan berpasangan sub kriteria Jumlah_Alat_Masuk
    #5.2.4 Normalisasi data matriks sub kriteria Jumlah_Alat_Masuk
    #5.2.5 Bobot sub kriteria Jumlah_Alat_Masuk
    #5.2.6 Grafik Bobot Sub Kriteria Jumlah_Alat_Masuk
    #5.2.7 Hasil data matriks sub kriteria Jumlah_Alat_Masuk
#5.3 Sub Kriteria Harga_Per_Alat
    #5.3.1 Perbandingan berpasangan sub kriteria Harga_Per_Alat
    #5.3.2 Penilaian expert sub kriteria Harga_Per_Alat
    #5.3.3 Tabel matriks perbandingan berpasangan sub kriteria Harga_Per_Alat
    #5.3.4 Normalisasi data matriks sub kriteria Harga_Per_Alat
    #5.3.5 Bobot sub kriteria Harga_Per_Alat
    #5.3.6 Grafik Bobot Sub Kriteria Harga_Per_Alat
    #5.3.7 Hasil data matriks sub kriteria Harga_Per_Alat
#5.4 Sub Kriteria Waktu_Penyelesaian
    #5.4.1 Perbandingan berpasangan sub kriteria Waktu_Penyelesaian
    #5.4.2 Penilaian expert sub kriteria Waktu_Penyelesaian
    #5.4.3 Tabel matriks perbandingan berpasangan sub kriteria Waktu_Penyelesaian
    #5.4.4 Normalisasi data matriks sub kriteria Waktu_Penyelesaian
    #5.4.5 Bobot sub kriteria Waktu_Penyelesaian
    #5.4.6 Grafik Bobot Sub Kriteria Waktu_Penyelesaian
    #5.4.7 Hasil data matriks sub kriteria Waktu_Penyelesaian
#5.5 Sub Kriteria Ulasan_Pelanggan
    #5.5.1 Perbandingan berpasangan sub kriteria Ulasan_Pelanggan
    #5.5.2 Penilaian expert sub kriteria Ulasan_Pelanggan
    #5.5.3 Tabel matriks perbandingan berpasangan sub kriteria Ulasan_Pelanggan
    #5.5.4 Normalisasi data matriks sub kriteria Ulasan_Pelanggan
    #5.5.5 Bobot sub kriteria Ulasan_Pelanggan
    #5.5.6 Grafik Bobot Sub Kriteria Ulasan_Pelanggan
    #5.5.7 Hasil data matriks sub kriteria Ulasan_Pelanggan

# Step 6: Memeriksa Konsistensi Data
#6.1 Rasio Konsistensi Kriteria
    #6.1.1 EMaks / λmaks kriteria
    #6.1.2 Indeks konsistensi kriteria
    #6.1.3 Rasio konsistensi kriteria
    #6.1.4 Memeriksa konsistensi data kriteria
    #6.1.5 Hasil rasio konsistensi kriteria

#6.2 Rasio Konsistensi Sub Kriteria Jumlah_Pelanggan
    #6.2.1 EMaks / λmaks sub kriteria Jumlah_Pelanggan
    #6.2.2 Indeks konsistensi sub kriteria Jumlah_Pelanggan
    #6.2.3 Rasio konsistensi sub kriteria Jumlah_Pelanggan
    #6.2.4 Memeriksa konsistensi Data sub kriteria Jumlah_Pelanggan
    #6.2.5 Hasil rasio konsistensi sub kriteria Jumlah_Pelanggan

#6.3 Rasio Konsistensi Sub Kriteria Jumlah_Alat_Masuk
    #6.3.1 EMaks / λmaks sub kriteria Jumlah_Alat_Masuk
    #6.3.2 Indeks konsistensi sub kriteria Jumlah_Alat_Masuk
    #6.3.3 Rasio konsistensi sub kriteria Jumlah_Alat_Masuk
    #6.3.4 Memeriksa konsistensi Data Sub kriteria Jumlah_Alat_Masuk
    #6.3.5 Hasil rasio konsistensi Sub kriteria Jumlah_Alat_Masuk

#6.4 Rasio Konsistensi Sub Kriteria Harga_Per_Alat
    #6.4.1 EMaks / λmaks sub kriteria Harga_Per_Alat
    #6.4.2 Indeks konsistensi sub kriteria Harga_Per_Alat
    #6.4.3 Rasio konsistensi sub kriteria Harga_Per_Alat
    #6.4.4 Memeriksa konsistensi Data sub kriteria Harga_Per_Alat
    #6.4.5 Hasil rasio konsistensi sub kriteria Harga_Per_Alat

#6.5 Rasio Konsistensi Sub Kriteria Waktu_Penyelesaian
    #6.5.1 EMaks / λmaks sub kriteria Waktu_Penyelesaian
    #6.5.2 Indeks konsistensi sub kriteria Waktu_Penyelesaian
    #6.5.3 Rasio konsistensi sub kriteria Waktu_Penyelesaian
    #6.5.4 Memeriksa konsistensi Data sub kriteria Waktu_Penyelesaian
    #6.5.5 Hasil rasio konsistensi sub kriteria Waktu_Penyelesaian

#6.6 Rasio Konsistensi Sub Kriteria Ulasan_Pelanggan
    #6.6.1 EMaks / λmaks sub kriteria Ulasan_Pelanggan
    #6.6.2 Indeks konsistensi sub kriteria Ulasan_Pelanggan
    #6.6.3 Rasio konsistensi sub kriteria Ulasan_Pelanggan
    #6.6.4 Memeriksa konsistensi Data sub kriteria Ulasan_Pelanggan
    #6.6.5 Hasil rasio konsistensi sub kriteria Ulasan_Pelanggan

# Step 7: Ranking
#7.1 Rekap bobot kriteria dari step 4.2 dan sub kriteria dari step 5.1.5, 5.2.5, 5.3.5, 5.4.5, dan 5.5.5
#7.2 Input data 1 periode
#7.3 Hitung bobot alternatif dengan perkalian bobot kriteria dan sub kriteria yang bersangkutan dan kemudian jumlahkan semua bobot kriteria dari alternatif tersebut.
#7.4 Hasil akhirnya adalah kesimpulan dari evaluasi penjualan 1 periode dalam bentuk perankingan setiap alternatif.

# %% [markdown]
# ##  Step 1 :	Mendefinisikan permasalahan dan penentuan tujuan / solusi

# %%
#1.1 Rumusan masalah
#Seorang Manajer bertanggungjawab mengawasi keberlangsungan hidup perusahaan. Untuk membantu manajer dalam menentukan pemilihan produk untuk menentukan strategi bisnis yang perlu untuk diterapkan sesuai dengan kebutuhan perusahaan dibutuhkan evaluasi penjualan dengan cara pemeringkatan setiap produk.

#1.2 Tujuan / solusi
#Peringkat Terhadap Kualitas Penjualan Alat Per Periode.

#1.3 Penentuan kriteria, sub kriteria, dan alternatif
#Berdasarkan hasil survei dan penilaian expert, disimpulkan bahwa kriteria, sub kriteria, dan alternatif dari permasalahan tesebut untuk mencari peringkat kualitas penjualan alat sebagai berikut:

#I. 5 Kriteria dan masing - masing kriteria memiliki 3 Sub Kriteria sebagai berikut :

#1. Jumlah pelanggan
#   1) Kurang dari 3
#   2) 3 sampai 5
#   3) Lebih dari 5
#2. Jumlah alat masuk
#   1) Kurang dari 50
#   2) 50 sampai 100
#   3) Lebih dari 100
#3. Harga per alat
#   1) Kurang dari 200.000
#   2) 200.000 sampai 350.000
#   3)Lebih dari 350.000
#4. Waktu penyelesaian
#   1) Terlambat
#   2) Tepat Waktu
#   3) Sangat Cepat
#5. Ulasan pelanggan
#   1) Kurang Puas
#   2) Puas
#   3) Sangat Puas
#II. Alternatif Alat

#Dari 17 jenis alat yang pernah diterima oleh perusahaan, diambil 4 jenis alat berdasarkan frekuensi kedatangan dan kalibrasi tertinggi serta selalu datang setiap bulan adalah sebagai berikut ini :

#1. Plug Gauge
#2. Thread Plug Gauge
#3. Thread Ring Gauge
#4. Instrument

# %% [markdown]
# ## Step 2 :	Menyusun masalah ke dalam struktur hierarki yang diawali tujuan utama

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import library gambar

# !pip install pillow
from PIL import Image
Hierarki_PT_XYZ = Image.open('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/Struktur_AHP_PT_XYZ.jpeg')
Hierarki_PT_XYZ
# Out:
# ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-e8ec244703e0> in <cell line: 3>()
#       1 get_ipython().system('pip install pillow')
#       2 from PIL import Image
# ----> 3 Hierarki_PT_XYZ = Image.open('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/Struktur_AHP_PT_XYZ.jpeg')
#       4 Hierarki_PT_XYZ
#
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py in open(fp, mode, formats)
#    3225
#    3226     if filename:
# -> 3227         fp = builtins.open(filename, "rb")
#    3228         exclusive_fp = True
#    3229
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/Struktur_AHP_PT_XYZ.jpeg'

# %% [markdown]
# ## Step 3 : Membuat Matriks Perbandingan Berpasangan Terhadap Kriteria (Pairwise Comparison Matrix)

# %%
#STEP 3.1 Perbandingan berpasangan setiap kriteria

#Untuk setiap kriteria dilakukan perbandingan dengan kriteria lainnya, akan didapatkan pasangan:
#(JP,JAM), (JP,HPA), (JP,WP), (JP,UP), (JAM,HPA), (JAM,WP), (JAM,UP), (HPA,WP), (HPA,UP), (WP,UP)
#Seluruh pasangan disimpan di dalam sebuah tabel matriks.

# %%
#STEP 3.2 Penilaian Expert Terhadap Kriteria

# Mengimport libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Penilaian dari 3 Expert Terhadap Kriteria
pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'expert_kriteria')

# %%
#STEP 3.3 Tabel Matriks Perbandingan Berpasangan Kriteria
# Menampilkan tabel matriks perbandingan berpasangan berdasarkan penilaian expert
criteria_comparison = pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'kriteria')
criteria_comparison

# %% [markdown]
# ## Step 4 : Eigen Vektor Normalisasi Kriteria

# %%
#STEP 4.1 Normalisasi Data Matriks Kriteria

normalization_criteria = criteria_comparison.copy()
for col in ['Jumlah Pelanggan','Jumlah Alat Masuk','Harga Per Alat','Waktu Penyelesaian','Ulasan Pelanggan']:
    normalization_criteria[col] = normalization_criteria[col] / normalization_criteria[col].sum()
normalization_criteria
# Out:
#              Kriteria  Jumlah Pelanggan  Jumlah Alat Masuk  Harga Per Alat  \
# 0    Jumlah Pelanggan          0.052338           0.053396        0.049969
# 1   Jumlah Alat Masuk          0.452909           0.462060        0.653803
# 2      Harga Per Alat          0.089497           0.060386        0.085445
# 3  Waktu Penyelesaian          0.325254           0.256680        0.160814
# 4    Ulasan Pelanggan          0.080002           0.167478        0.049969
#
#    Waktu Penyelesaian  Ulasan Pelanggan
# 0            0.040077          0.081410
# 1            0.448337          0.343319
# 2            0.132331          0.212788
# 3            0.249057          0.238044
# 4            0.130197          0.124439

# %%
#STEP 4.2 Mencari Bobot Setiap Kriteria

# Menghitung bobot untuk setiap kriteria
Bobot_Jumlah_Pelanggan = (normalization_criteria['Jumlah Pelanggan'][0] + normalization_criteria['Jumlah Alat Masuk'][0] + normalization_criteria['Harga Per Alat'][0] + normalization_criteria['Waktu Penyelesaian'][0] + normalization_criteria['Ulasan Pelanggan'][0])/normalization_criteria['Kriteria'].count()
Bobot_Jumlah_Alat_Masuk = (normalization_criteria['Jumlah Pelanggan'][1] + normalization_criteria['Jumlah Alat Masuk'][1] + normalization_criteria['Harga Per Alat'][1] + normalization_criteria['Waktu Penyelesaian'][1] + normalization_criteria['Ulasan Pelanggan'][1])/normalization_criteria['Kriteria'].count()
Bobot_Harga_Per_Alat = (normalization_criteria['Jumlah Pelanggan'][2] + normalization_criteria['Jumlah Alat Masuk'][2] + normalization_criteria['Harga Per Alat'][2] + normalization_criteria['Waktu Penyelesaian'][2] + normalization_criteria['Ulasan Pelanggan'][2])/normalization_criteria['Kriteria'].count()
Bobot_Waktu_Penyelesaian = (normalization_criteria['Jumlah Pelanggan'][3] + normalization_criteria['Jumlah Alat Masuk'][3] + normalization_criteria['Harga Per Alat'][3] + normalization_criteria['Waktu Penyelesaian'][3] + normalization_criteria['Ulasan Pelanggan'][3])/normalization_criteria['Kriteria'].count()
Bobot_Ulasan_Pelanggan = (normalization_criteria['Jumlah Pelanggan'][4] + normalization_criteria['Jumlah Alat Masuk'][4] + normalization_criteria['Harga Per Alat'][4] + normalization_criteria['Waktu Penyelesaian'][4] + normalization_criteria['Ulasan Pelanggan'][4])/normalization_criteria['Kriteria'].count()

matriks_bobot_kriteria = {'Kriteria' : ['Jumlah Pelanggan','Jumlah Alat Masuk','Harga Per Alat','Waktu Penyelesaian',
                                        'Ulasan Pelanggan'],
                          'Bobot' : [Bobot_Jumlah_Pelanggan, Bobot_Jumlah_Alat_Masuk, Bobot_Harga_Per_Alat,
                                     Bobot_Waktu_Penyelesaian, Bobot_Ulasan_Pelanggan]}
# dataframe bobot kriteria
bobot_kriteria = pd.DataFrame(matriks_bobot_kriteria).set_index('Kriteria')
bobot_kriteria

# %%
#STEP 4.3 Grafik Bobot Kriteria

kriteria = ['Jumlah Pelanggan','Jumlah Alat Masuk','Harga Per Alat','Waktu Penyelesaian','Ulasan Pelanggan']
nilai_kriteria = [Bobot_Jumlah_Pelanggan, Bobot_Jumlah_Alat_Masuk, Bobot_Harga_Per_Alat, Bobot_Waktu_Penyelesaian, Bobot_Ulasan_Pelanggan]
plt.figure(figsize=(10,4))
plt.bar(kriteria, nilai_kriteria, color = ['blue', 'Green', 'red', 'orange','yellow'])
plt.title('Perbandingan Kriteria')
plt.xlabel('Kriteria')
plt.ylabel('Bobot Kriteria')

plt.show()

# %%
#STEP 4.4 Hasil Data Matriks

#Hasil akhir dari proses pencarian bobot kriteria adalah :

#Kriteria Jumlah_Alat_Masuk merupakan kriteria yang paling penting dari semua kriteria, dengan bobot 0.472
#1. Kriteria Waktu_Penyelesaian dengan bobot 0.246
#2. Kriteria Harga_Per_Alat dengan bobot 0.116
#3. Kriteria Ulasan_Pelanggan dengan bobot 0.11
#4. Kriteria Jumlah_Pelanggan dengan bobot 0.055

# %% [markdown]
# ## Step 5 : Mengulang Tahap 3 dan 4 Untuk Seluruh Tingkat Hierarki

# %% [markdown]
# ### 5.1 Sub Kriteria Jumlah_Pelanggan

# %%
#STEP 5.1.1 Perbandingan berpasangan sub kriteria Jumlah_Pelanggan

#Untuk setiap sub kriteria jumlah pelanggan dilakukan perbandingan dengan sub kriteria jumlah pelanggan lainnya, akan didapatkan pasangan :
#(<3 - 3-5), (<3 - >5), (3-5 - >5)
#Seluruh pasangan disimpan di dalam sebuah tabel matriks.

# %%
#STEP 5.1.2 Penilaian expert sub kriteria Jumlah_Pelanggan

# Penilaian dari 3 Expert Terhadap Sub Kriteria Jumlah Pelanggan
pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'expert_JP')
# Out:
#          JP        E1        E2        E3   Geomean
# 0  <3 - 3-5  0.166667  0.200000  0.142857  0.168239
# 1   <3 - >5  0.250000  0.200000  0.200000  0.215443
# 2  3-5 - >5  2.000000  0.333333  0.333333  0.605707

# %%
#STEP 5.1.3 Tabel matriks perbandingan berpasangan sub kriteria Jumlah_Pelanggan

# Membaca dataframe dari file excel
jumlah_pelanggan_comparison = pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'jumlah_pelanggan')
jumlah_pelanggan_comparison

# %%
#STEP 5.1.4 Normalisasi data matriks sub kriteria Jumlah_Pelanggan

normalization_jumlah_pelanggan = jumlah_pelanggan_comparison.copy()
for col in ['<3','3-5','>5']:
    normalization_jumlah_pelanggan[col] = normalization_jumlah_pelanggan[col] / normalization_jumlah_pelanggan[col].sum()
normalization_jumlah_pelanggan

# %%
#STEP 5.1.5 Bobot sub kriteria Jumlah_Pelanggan

SK_JP1 = (normalization_jumlah_pelanggan['<3'][0] + normalization_jumlah_pelanggan['3-5'][0] + normalization_jumlah_pelanggan['>5'][0])/normalization_jumlah_pelanggan['SK Jumlah Pelanggan'].count()
SK_JP2 = (normalization_jumlah_pelanggan['<3'][1] + normalization_jumlah_pelanggan['3-5'][1] + normalization_jumlah_pelanggan['>5'][1])/normalization_jumlah_pelanggan['SK Jumlah Pelanggan'].count()
SK_JP3 = (normalization_jumlah_pelanggan['<3'][2] + normalization_jumlah_pelanggan['3-5'][2] + normalization_jumlah_pelanggan['>5'][2])/normalization_jumlah_pelanggan['SK Jumlah Pelanggan'].count()

matriks_bobot_jumlah_pelanggan = {'SK Jumlah Pelanggan' : ['<3','3-5','>5'],
                          'Bobot' : [SK_JP1, SK_JP2, SK_JP3]}
# dataframe bobot sub kriteria
bobot_jumlah_pelanggan = pd.DataFrame(matriks_bobot_jumlah_pelanggan).set_index('SK Jumlah Pelanggan')
bobot_jumlah_pelanggan

# %%
#STEP 5.1.6 Grafik Bobot Sub Kriteria Jumlah_Pelanggan

SK_JP = ['<3','3-5','>5']
nilai_SK_JP = [SK_JP1, SK_JP2, SK_JP3]
plt.bar(SK_JP,nilai_SK_JP, color = ['red', 'Green', 'blue'])
plt.title('Perbandingan Sub Kriteria Jumlah Pelanggan')
plt.xlabel('Sub Kriteria')
plt.ylabel('Bobot SK Jumlah Pelanggan')

plt.show()

# %%
#STEP 5.1.7 Hasil data matriks sub kriteria Jumlah_Pelanggan

# Hasil akhir dari proses pencarian bobot sub kriteria Jumlah_Pelanggan adalah :
# 1. Jumlah pelanggan lebih dari 5 memiliki bobot tertinggi 0.511785.
# 2. Dari 3 kategori jumlah pelanggan yang dianalisis, jumlah pelanggan diatas 5 paling penting daripada jumlah pelanggan kurang dari 5.

# %% [markdown]
# ### 5.2 Sub Kriteria Jumlah_Alat_Masuk

# %%
#STEP 5.2.1 Perbandingan berpasangan sub kriteria Jumlah_Alat_Masuk

# Untuk setiap sub kriteria jumlah alat masuk dilakukan perbandingan dengan sub kriteria jumlah alat masuk lainnya, akan didapatkan pasangan :
# (<50 - 50-100), (<50 - >100), (50-100 - >100)
# Seluruh pasangan disimpan di dalam sebuah tabel matriks.

# %%
#STEP 5.2.2 Penilaian expert sub kriteria Jumlah_Alat_Masuk

# Penilaian dari 3 Expert Terhadap Sub Kriteria Jumlah Alat Masuk
pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'expert_JA')
# Out:
#              JAM        E1   E2        E3   Geomean
# 0   <50 - 50-100  0.333333  0.2  0.166667  0.223144
# 1     <50 - >100  0.250000  0.5  0.250000  0.314980
# 2  50-100 - >100  2.000000  2.0  0.500000  1.259921

# %%
#STEP 5.2.3 Tabel matriks perbandingan berpasangan sub kriteria Jumlah_Alat_Masuk

# Membaca dataframe dari file excel
jumlah_alat_masuk_comparison = pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'jumlah_alat')
jumlah_alat_masuk_comparison
# Out:
#   SK Jumlah Alat Masuk       <50    50-100      >100
# 0                  <50  1.000000  0.223144  0.314980
# 1               50-100  4.481405  1.000000  1.259921
# 2                 >100  3.174802  0.793701  1.000000

# %%
#STEP 5.2.4 Normalisasi data matriks sub kriteria Jumlah_Alat_Masuk

normalization_jumlah_alat_masuk = jumlah_alat_masuk_comparison.copy()
for col in ['<50','50-100','>100']:
    normalization_jumlah_alat_masuk[col] = normalization_jumlah_alat_masuk[col] / normalization_jumlah_alat_masuk[col].sum()
normalization_jumlah_alat_masuk
# Out:
#   SK Jumlah Alat Masuk       <50    50-100      >100
# 0                  <50  0.115524  0.110640  0.122327
# 1               50-100  0.517710  0.495824  0.489308
# 2                 >100  0.366766  0.393536  0.388364

# %%
#STEP 5.2.5 Bobot sub kriteria Jumlah_Alat_Masuk

SK_JAM1 = (normalization_jumlah_alat_masuk['<50'][0] + normalization_jumlah_alat_masuk['50-100'][0] + normalization_jumlah_alat_masuk['>100'][0])/normalization_jumlah_alat_masuk['SK Jumlah Alat Masuk'].count()
SK_JAM2 = (normalization_jumlah_alat_masuk['<50'][1] + normalization_jumlah_alat_masuk['50-100'][1] + normalization_jumlah_alat_masuk['>100'][1])/normalization_jumlah_alat_masuk['SK Jumlah Alat Masuk'].count()
SK_JAM3 = (normalization_jumlah_alat_masuk['<50'][2] + normalization_jumlah_alat_masuk['50-100'][2] + normalization_jumlah_alat_masuk['>100'][2])/normalization_jumlah_alat_masuk['SK Jumlah Alat Masuk'].count()

matriks_bobot_jumlah_alat_masuk = {'SK Jumlah Alat Masuk' : ['<50','50-100','>100'],
                                   'Bobot' : [SK_JAM1, SK_JAM2, SK_JAM3]}
# dataframe bobot sub kriteria
bobot_jumlah_alat_masuk = pd.DataFrame(matriks_bobot_jumlah_alat_masuk).set_index('SK Jumlah Alat Masuk')
bobot_jumlah_alat_masuk
# Out:
#                          Bobot
# SK Jumlah Alat Masuk
# <50                   0.116164
# 50-100                0.500947
# >100                  0.382889

# %%
#STEP 5.2.6 Grafik Bobot Sub Kriteria Jumlah_Alat_Masuk

SK_JAM = ['<50','50-100','>100']
nilai_SK_JAM = [SK_JAM1, SK_JAM2, SK_JAM3]
plt.bar(SK_JAM, nilai_SK_JAM, color = ['red', 'Green', 'blue'])
plt.title('Perbandingan Sub Kriteria Jumlah Alat Masuk')
plt.xlabel('Sub Kriteria')
plt.ylabel('Bobot SK Jumlah Alat Masuk')

plt.show()

# %%
#STEP 5.2.7 Hasil data matriks sub kriteria Jumlah_Alat_Masuk

# Hasil akhir dari proses pencarian bobot sub kriteria Jumlah_Alat_Masuk adalah :
# 1. Jumlah alat antara **50 sampai 100 memiliki bobot tertinggi 0.500947**.
# 2. Dari 3 kategori jumlah alat yang dianalisis, jumlah alat **50 sampai 100 paling penting** daripada jumlah alat kurang dari 50 atau lebih dari 100.

# %% [markdown]
# ### 5.3 Sub Kriteria Harga_Per_Alat

# %%
#STEP 5.3.1 Perbandingan berpasangan sub kriteria Harga_Per_Alat

# Untuk setiap sub kriteria harga alat dilakukan perbandingan dengan sub kriteria harga alat lainnya, akan didapatkan pasangan :
# (<200.000 - 200.000 – 350.000), (<200.000 - >350.000), (200.000 – 350.000 - >350.000)
# Seluruh pasangan disimpan di dalam sebuah tabel matriks.

# %%
#STEP 5.3.2 Penilaian expert sub kriteria Harga_Per_Alat

# Penilaian dari 3 Expert Terhadap Sub Kriteria Harga Alat Masuk
pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'expert_HA')
# Out:
#                             HPA        E1        E2        E3   Geomean
# 0  <200.000 - 200.000 – 350.000  0.166667  0.200000  0.142857  0.168239
# 1           <200.000 - >350.000  0.166667  0.166667  0.200000  0.177110
# 2  200.000 – 350.000 - >350.000  0.500000  3.000000  0.333333  0.793701

# %%
#STEP 5.3.3 Tabel matriks perbandingan berpasangan sub kriteria Harga_Per_Alat

# Membaca dataframe dari file excel
harga_per_alat_comparison = pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'harga_alat')
harga_per_alat_comparison
# Out:
#    SK Harga Per Alat  <200.000  200.000 – 350.000  >350.000
# 0           <200.000  1.000000           0.168239  0.177110
# 1  200.000 – 350.000  5.943922           1.000000  0.793701
# 2           >350.000  5.646216           1.259921  1.000000

# %%
#STEP 5.3.4 Normalisasi data matriks sub kriteria Harga_Per_Alat

normalization_harga_per_alat = harga_per_alat_comparison.copy()
for col in ['<200.000','200.000 – 350.000','>350.000']:
    normalization_harga_per_alat[col] = normalization_harga_per_alat[col] / normalization_harga_per_alat[col].sum()
normalization_harga_per_alat
# Out:
#    SK Harga Per Alat  <200.000  200.000 – 350.000  >350.000
# 0           <200.000  0.079427           0.069287  0.089866
# 1  200.000 – 350.000  0.472109           0.411834  0.402728
# 2           >350.000  0.448463           0.518879  0.507406

# %%
#STEP 5.3.5 Bobot sub kriteria Harga_Per_Alat

SK_HPA1 = (normalization_harga_per_alat['<200.000'][0] + normalization_harga_per_alat['200.000 – 350.000'][0] + normalization_harga_per_alat['>350.000'][0])/normalization_harga_per_alat['SK Harga Per Alat'].count()
SK_HPA2 = (normalization_harga_per_alat['<200.000'][1] + normalization_harga_per_alat['200.000 – 350.000'][1] + normalization_harga_per_alat['>350.000'][1])/normalization_harga_per_alat['SK Harga Per Alat'].count()
SK_HPA3 = (normalization_harga_per_alat['<200.000'][2] + normalization_harga_per_alat['200.000 – 350.000'][2] + normalization_harga_per_alat['>350.000'][2])/normalization_harga_per_alat['SK Harga Per Alat'].count()

matriks_bobot_harga_per_alat = {'SK Harga Per Alat' : ['<200.000','200.000 – 350.000','>350.000'],
                              'Bobot' : [SK_HPA1, SK_HPA2, SK_HPA3]}
# dataframe bobot sub kriteria
bobot_harga_per_alat = pd.DataFrame(matriks_bobot_harga_per_alat).set_index('SK Harga Per Alat')
bobot_harga_per_alat
# Out:
#                       Bobot
# SK Harga Per Alat
# <200.000           0.079527
# 200.000 – 350.000  0.428891
# >350.000           0.491583

# %%
#STEP 5.3.6 Grafik Bobot Sub Kriteria Harga_Per_Alat

SK_HPA = ['<200.000','200.000 – 350.000','>350.000']
nilai_SK_HPA = [SK_HPA1, SK_HPA2, SK_HPA3]
plt.bar(SK_HPA,nilai_SK_HPA, color = ['red', 'Green', 'blue'])
plt.title('Perbandingan Sub Kriteria Harga Per Alat')
plt.xlabel('Sub Kriteria')
plt.ylabel('Bobot SK Harga Per Alat')

plt.show()

# %%
#STEP 5.3.7 Hasil data matriks sub kriteria Harga_Per_Alat

# Hasil akhir dari proses pencarian bobot sub kriteria Harga_Per_Alat adalah :
# 1. Harga alat **diatas 350.000 memiliki bobot tertinggi 0.491583**.
# 2. Dari 3 kategori harga alat yang dianalisis, harga alat **diatas 350.000 lebih penting** daripada harga alat dibawah 350.000.

# %% [markdown]
# ### 5.4 Sub Kriteria Waktu_Penyelesaian

# %%
#STEP 5.4.1 Perbandingan berpasangan sub kriteria Waktu_Penyelesaian

# Untuk setiap sub kriteria waktu penyelesaian dilakukan perbandingan dengan sub kriteria waktu penyelesaian lainnya, akan didapatkan pasangan :
# (Terlambat - Tepat Waktu), (Terlambat - Sangat Cepat), (Tepat Waktu - Sangat Cepat)
# Seluruh pasangan disimpan di dalam sebuah tabel matriks.

# %%
#STEP 5.4.2 Penilaian expert sub kriteria Waktu_Penyelesaian

# Penilaian dari 3 Expert Terhadap Sub Kriteria Waktu Penyelesaian
pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'expert_WP')
# Out:
#                            WP        E1        E2        E3   Geomean
# 0     Terlambat - Tepat Waktu  0.111111  0.111111  0.111111  0.111111
# 1    Terlambat - Sangat Cepat  0.142857  0.166667  0.142857  0.150390
# 2  Tepat Waktu - Sangat Cepat  0.500000  2.000000  0.500000  0.793701

# %%
#STEP 5.4.3 Tabel matriks perbandingan berpasangan sub kriteria Waktu_Penyelesaian

waktu_penyelesaian_comparison = pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'waktu_penyelesaian')
waktu_penyelesaian_comparison
# Out:
#   SK Waktu Penyelesaian  Terlambat  Tepat Waktu  Sangat Cepat
# 0             Terlambat     1.0000     0.111111      0.150390
# 1           Tepat Waktu     9.0000     1.000000      0.793701
# 2          Sangat Cepat     6.6494     1.259921      1.000000

# %%
#STEP 5.4.4 Normalisasi data matriks sub kriteria Waktu_Penyelesaian

normalization_waktu_penyelesaian = waktu_penyelesaian_comparison.copy()
for col in ['Terlambat','Tepat Waktu','Sangat Cepat']:
    normalization_waktu_penyelesaian[col] = normalization_waktu_penyelesaian[col] / normalization_waktu_penyelesaian[col].sum()
normalization_waktu_penyelesaian
# Out:
#   SK Waktu Penyelesaian  Terlambat  Tepat Waktu  Sangat Cepat
# 0             Terlambat   0.060062     0.046862      0.077357
# 1           Tepat Waktu   0.540560     0.421757      0.408263
# 2          Sangat Cepat   0.399378     0.531381      0.514379

# %%
#STEP 5.4.5 Bobot sub kriteria Waktu_Penyelesaian

SK_WP1 = (normalization_waktu_penyelesaian['Terlambat'][0] + normalization_waktu_penyelesaian['Tepat Waktu'][0] + normalization_waktu_penyelesaian['Sangat Cepat'][0])/normalization_waktu_penyelesaian['SK Waktu Penyelesaian'].count()
SK_WP2 = (normalization_waktu_penyelesaian['Terlambat'][1] + normalization_waktu_penyelesaian['Tepat Waktu'][1] + normalization_waktu_penyelesaian['Sangat Cepat'][1])/normalization_waktu_penyelesaian['SK Waktu Penyelesaian'].count()
SK_WP3 = (normalization_waktu_penyelesaian['Terlambat'][2] + normalization_waktu_penyelesaian['Tepat Waktu'][2] + normalization_waktu_penyelesaian['Sangat Cepat'][2])/normalization_waktu_penyelesaian['SK Waktu Penyelesaian'].count()

matriks_bobot_waktu_penyelesaian= {'SK Waktu Penyelesaian' : ['Terlambat','Tepat Waktu','Sangat Cepat'],
                                  'Bobot' : [SK_WP1, SK_WP2, SK_WP3]}
# dataframe bobot sub kriteria
bobot_waktu_penyelesaian= pd.DataFrame(matriks_bobot_waktu_penyelesaian).set_index('SK Waktu Penyelesaian')
bobot_waktu_penyelesaian
# Out:
#                           Bobot
# SK Waktu Penyelesaian
# Terlambat              0.061427
# Tepat Waktu            0.456860
# Sangat Cepat           0.481713

# %%
#STEP 5.4.6 Grafik Bobot Sub Kriteria Waktu_Penyelesaian

SK_WP = ['Terlambat','Tepat Waktu','Sangat Cepat']
nilai_SK_WP = [SK_WP1, SK_WP2, SK_WP3]
plt.bar(SK_WP,nilai_SK_WP, color = ['red', 'Green', 'blue'])
plt.title('Perbandingan Sub Kriteria Waktu Penyelesaian')
plt.xlabel('Sub Kriteria')
plt.ylabel('Bobot SK Waktu Penyelesaian')

plt.show()

# %%
#STEP 5.4.7 Hasil data matriks sub kriteria Waktu_Penyelesaian

# Hasil akhir dari proses pencarian bobot sub kriteria Waktu_Penyelesaian adalah :
# 1. Waktu Penyelesaian yang terbaik adalah sangat cepat memiliki bobot tertinggi 0.481713.
# 2. Dari 3 kategori waktu penyelesaian yang dianalisis, waktu penyelesaian yang sangat cepat paling penting daripada waktu penyelesaian terlambat dan tepat waktu.

# %% [markdown]
# ### 5.5 Sub Kriteria Ulasan_Pelanggan

# %%
#STEP 5.5.1 Perbandingan berpasangan sub kriteria Ulasan_Pelanggan

#Untuk setiap sub kriteria ulasan pelanggan dilakukan perbandingan dengan sub kriteria ulasan pelanggan lainnya, akan didapatkan pasangan :
#(Kurang Puas - Puas), (Kurang Puas - Sangat Puas), (Puas - Sangat Puas)
#Seluruh pasangan disimpan di dalam sebuah tabel matriks

# %%
#STEP 5.5.2 Penilaian expert sub kriteria Ulasan_Pelanggan

# Penilaian dari 3 Expert Terhadap sub kriteria Ulasan Pelanggan
pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'expert_UP')
# Out:
#                           UP        E1        E2        E3   Geomean
# 0         Kurang Puas - Puas  0.166667  0.142857  0.142857  0.150390
# 1  Kurang Puas - Sangat Puas  0.125000  0.125000  0.111111  0.120187
# 2         Puas - Sangat Puas  0.500000  2.000000  0.250000  0.629961

# %%
#STEP 5.5.3 Tabel matriks perbandingan berpasangan sub kriteria Ulasan_Pelanggan

# Membaca dataframe dari file excel
ulasan_pelanggan_comparison = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'ulasan_pelanggan')
ulasan_pelanggan_comparison
# Out:
#   SK Ulasan Pelanggan  Kurang Puas      Puas  Sangat Puas
# 0         Kurang Puas     1.000000  0.150390     0.120187
# 1                Puas     6.649400  1.000000     0.629961
# 2         Sangat Puas     8.320335  1.587401     1.000000

# %%
#STEP 5.5.4 Normalisasi data matriks sub kriteria Ulasan_Pelanggan

normalization_ulasan_pelanggan = ulasan_pelanggan_comparison.copy()
for col in ['Kurang Puas','Puas','Sangat Puas']:
    normalization_ulasan_pelanggan[col] = normalization_ulasan_pelanggan[col] / normalization_ulasan_pelanggan[col].sum()
normalization_ulasan_pelanggan
# Out:
#   SK Ulasan Pelanggan  Kurang Puas      Puas  Sangat Puas
# 0         Kurang Puas     0.062618  0.054931     0.068673
# 1                Puas     0.416375  0.365258     0.359947
# 2         Sangat Puas     0.521006  0.579811     0.571380

# %%
#STEP 5.5.5 Bobot sub kriteria Ulasan_Pelanggan

SK_UP1 = (normalization_ulasan_pelanggan['Kurang Puas'][0] + normalization_ulasan_pelanggan['Puas'][0] + normalization_ulasan_pelanggan['Sangat Puas'][0])/normalization_ulasan_pelanggan['SK Ulasan Pelanggan'].count()
SK_UP2 = (normalization_ulasan_pelanggan['Kurang Puas'][1] + normalization_ulasan_pelanggan['Puas'][1] + normalization_ulasan_pelanggan['Sangat Puas'][1])/normalization_ulasan_pelanggan['SK Ulasan Pelanggan'].count()
SK_UP3 = (normalization_ulasan_pelanggan['Kurang Puas'][2] + normalization_ulasan_pelanggan['Puas'][2] + normalization_ulasan_pelanggan['Sangat Puas'][2])/normalization_ulasan_pelanggan['SK Ulasan Pelanggan'].count()
matriks_bobot_ulasan_pelanggan= {'SK Ulasan Pelanggan' : ['Kurang Puas','Puas','Sangat Puas'],
                              'Bobot' : [SK_UP1, SK_UP2, SK_UP3]}
# dataframe bobot sub kriteria
bobot_ulasan_pelanggan = pd.DataFrame(matriks_bobot_ulasan_pelanggan).set_index('SK Ulasan Pelanggan')
bobot_ulasan_pelanggan
# Out:
#                         Bobot
# SK Ulasan Pelanggan
# Kurang Puas          0.062074
# Puas                 0.380527
# Sangat Puas          0.557399

# %%
#STEP 5.5.5 Grafik Bobot Sub Kriteria Ulasan_Pelanggan

SK_UP = ['Kurang Puas','Puas','Sangat Puas']
nilai_SK_UP = [SK_UP1, SK_UP2, SK_UP3]
plt.bar(SK_UP,nilai_SK_UP, color = ['red', 'Green', 'blue'])
plt.title('Perbandingan Sub Kriteria Ulasan Pelanggan')
plt.xlabel('Sub Kriteria')
plt.ylabel('Bobot SK Ulasan Pelanggan')

plt.show()

# %%
#STEP 5.5.7 Hasil data matriks sub kriteria Ulasan_Pelanggan

# Hasil akhir dari proses pencarian bobot sub kriteria Ulasan_Pelanggann adalah :
# 1. Ulasan pelanggan sangat puas memiliki bobot tertinggi 0.557399.
# 2. Dari 3 kategori ulasan pelanggan yang dianalisis, ulasan pelanggan sangat puas paling penting daripada ulasan pelanggan kurang puas dan puas.
# 3. Nilai konsistensi data kriteria adalah 0,005 (CR)

# %% [markdown]
# ## Step 6 : Memeriksa Konsistensi Data

# %% [markdown]
# ### 6.1 Rasio Konsistensi Data Kriteria

# %%
#STEP 6.1.1 EMaks / λmaks Kriteria

# Mencari Jumlah Perbaris Kriteria dari perkalian matriks tabel perbandingan dengan bobot kriteria
criteria_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'kriteria').set_index('Kriteria')

jumlah_perbaris_kriteria = criteria_comparison_matrix.dot(bobot_kriteria)
jumlah_perbaris_kriteria['Jumlah Perbaris'] = jumlah_perbaris_kriteria.pop('Bobot')
jumlah_perbaris_kriteria
# Out:
#                     Jumlah Perbaris
# Kriteria
# Jumlah Pelanggan           0.289698
# Jumlah Alat Masuk          2.587515
# Harga Per Alat             0.592085
# Waktu Penyelesaian         1.282446
# Ulasan Pelanggan           0.562741

# %%
# pembagian jumlah perbaris dengan bobot setiap kriteria
Hasil_kriteria = jumlah_perbaris_kriteria.copy()
for x in ['Jumlah Perbaris']:
    Hasil_kriteria[x] = Hasil_kriteria[x] / bobot_kriteria['Bobot']
Emaks_kriteria = Hasil_kriteria[x].sum() / normalization_criteria['Kriteria'].count()
Emaks_kriteria
# Out:
# 5.223449917233494

# %%
#STEP 6.1.2 Indeks Konsistensi Kriteria

CI_kriteria = (Emaks_kriteria - normalization_criteria['Kriteria'].count()) / (normalization_criteria['Kriteria'].count()-1)
CI_kriteria
# Out:
# 0.055862479308373514

# %%
IR = {1:0, 2:0, 3:0.58, 4:0.9, 5:1.12, 6:1.24, 7:1.32, 8:1.41, 9:1.45, 10:1.49, 11:1.51, 12:1.48, 13:1.56, 14:1.57, 15:1.59}

# %%
#STEP 6.1.3 Rasio Konsistensi Kriteria

IR_kriteria = IR.get(normalization_criteria['Kriteria'].count(), None)
if IR_kriteria is not None:
    IR_kriteria
else:
    0
CR_kriteria = CI_kriteria / IR_kriteria
CR_kriteria
# Out:
# 0.04987721366819063

# %%
#STEP 6.1.4 Memeriksa Konsistensi Data Kriteria

if CR_kriteria < 0.1:
    print("Data sudah konsisten")
else:
    print("Data belum konsisten, lakukan penilaian ulang")
# Out:
# Data sudah konsisten

# %%
#STEP 6.1.5 Hasil rasio konsistensi kriteria
# Nilai konsistensi data kriteria adalah 0,050 (CR)

# %% [markdown]
# ### 6.2 Rasio Konsistensi Data Sub Kriteria Jumlah_Pelanggan

# %%
#STEP 6.2.1 EMaks / λmaks Sub Kriteria Jumlah_Pelanggan

# Mencari jumlah perbaris sub kriteria dari perkalian matriks tabel perbandingan dengan bobot sub kriteria
jumlah_pelanggan_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'jumlah_pelanggan').set_index('SK Jumlah Pelanggan')

jumlah_perbaris_JP = jumlah_pelanggan_comparison_matrix.dot(bobot_jumlah_pelanggan)
jumlah_perbaris_JP['Jumlah Perbaris'] = jumlah_perbaris_JP.pop('Bobot')
jumlah_perbaris_JP
# Out:
#                      Jumlah Perbaris
# SK Jumlah Pelanggan
# <3                          0.265673
# 3-5                         1.233752
# >5                          1.581276

# %%
#pembagian jumlah perbaris dengan bobot setiap sub kriteria
Hasil_jumlah_pelanggan = jumlah_perbaris_JP.copy()
for x in ['Jumlah Perbaris']:
    Hasil_jumlah_pelanggan[x] = Hasil_jumlah_pelanggan[x] / bobot_jumlah_pelanggan['Bobot']
Emaks_jumlah_pelanggan = Hasil_jumlah_pelanggan[x].sum() / jumlah_pelanggan_comparison['SK Jumlah Pelanggan'].count()
Emaks_jumlah_pelanggan
# Out:
# 3.0629615427520727

# %%
#STEP 6.2.2 Indeks Konsistensi Sub Kriteria Jumlah_Pelanggan

CI_jumlah_pelanggan = (Emaks_jumlah_pelanggan - jumlah_pelanggan_comparison['SK Jumlah Pelanggan'].count()) / (jumlah_pelanggan_comparison['SK Jumlah Pelanggan'].count()-1)
CI_jumlah_pelanggan
# Out:
# 0.03148077137603633

# %%
#STEP 6.2.3 Rasio Konsistensi Sub Kriteria Jumlah_Pelanggan

IR_jumlah_pelanggan = IR.get(jumlah_pelanggan_comparison['SK Jumlah Pelanggan'].count(), None)
if IR_jumlah_pelanggan is not None:
    IR_jumlah_pelanggan
else:
    0
CR_jumlah_pelanggan = CI_jumlah_pelanggan / IR_jumlah_pelanggan
CR_jumlah_pelanggan
# Out:
# 0.05427719202764885

# %%
#STEP 6.2.4 Memeriksa Konsistensi Data Sub Kriteria Jumlah_Pelanggan

if CR_jumlah_pelanggan < 0.1:
    print("Data sudah konsisten")
else:
    print("Data belum konsisten, lakukan penilaian ulang")
# Out:
# Data sudah konsisten

# %%
#STEP 6.2.5 Hasil rasio konsistensi Sub Kriteria Jumlah_Pelanggan
# Nilai konsistensi data sub kriteria Jumlah_Pelanggan adalah 0,054 (CR)

# %% [markdown]
# ### 6.3 Rasio Konsistensi Data Sub Kriteria Jumlah_Alat_Masuk

# %%
#STEP 6.3.1 EMaks / λmaks Sub Kriteria Jumlah_Alat_Masuk

# Mencari jumlah perbaris sub kriteria dari perkalian matriks tabel perbandingan dengan bobot sub kriteria
jumlah_alat_masuk_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'jumlah_alat').set_index('SK Jumlah Alat Masuk')

jumlah_perbaris_JAM = jumlah_alat_masuk_comparison_matrix.dot(bobot_jumlah_alat_masuk)
jumlah_perbaris_JAM['Jumlah Perbaris'] = jumlah_perbaris_JAM.pop('Bobot')
jumlah_perbaris_JAM
# Out:
#                       Jumlah Perbaris
# SK Jumlah Alat Masuk
# <50                          0.348550
# 50-100                       1.503934
# >100                         1.149288

# %%
#pembagian jumlah perbaris dengan bobot setiap sub kriteria
Hasil_jumlah_alat_masuk = jumlah_perbaris_JAM.copy()
for x in ['Jumlah Perbaris']:
    Hasil_jumlah_alat_masuk[x] = Hasil_jumlah_alat_masuk[x] / bobot_jumlah_alat_masuk['Bobot']
Emaks_jumlah_alat_masuk = Hasil_jumlah_alat_masuk[x].sum() / jumlah_alat_masuk_comparison['SK Jumlah Alat Masuk'].count()
Emaks_jumlah_alat_masuk
# Out:
# 3.0014352835475404

# %%
#STEP 6.3.2 Indeks konsistensi sub kriteria Jumlah_Alat_Masuk

CI_jumlah_alat_masuk = (Emaks_jumlah_alat_masuk - jumlah_alat_masuk_comparison['SK Jumlah Alat Masuk'].count()) / (jumlah_alat_masuk_comparison['SK Jumlah Alat Masuk'].count()-1)
CI_jumlah_alat_masuk
# Out:
# 0.0007176417737702057

# %%
#STEP 6.3.3 Rasio Konsistensi sub kriteria Jumlah_Alat_Masuk

IR_jumlah_alat_masuk = IR.get(jumlah_alat_masuk_comparison['SK Jumlah Alat Masuk'].count(), None)
if IR_jumlah_alat_masuk is not None:
    IR_jumlah_alat_masuk
else:
    0
CR_jumlah_alat_masuk = CI_jumlah_alat_masuk / IR_jumlah_alat_masuk
CR_jumlah_alat_masuk
# Out:
# 0.0012373134030520788

# %%
#STEP 6.3.4 Memeriksa konsistensi data sub kriteria Jumlah_Alat_Masuk

if CR_jumlah_alat_masuk < 0.1:
    print("Data sudah konsisten")
else:
    print("Data belum konsisten, lakukan penilaian ulang")
# Out:
# Data sudah konsisten

# %%
#STEP 6.3.5 Hasil rasio konsistensi sub kriteria Jumlah_Alat_Masuk
# Nilai konsistensi data sub kriteria Jumlah_Alat_Masuk adalah 0,001 (CR)

# %% [markdown]
# ### 6.4 Rasio Konsistensi Data Sub Kriteria Harga_Per_Alat

# %%
#STEP 6.4.1 EMaks / λmaks sub kriteria Harga_Per_Alat

# Mencari jumlah perbaris sub kriteria dari perkalian matriks tabel perbandingan dengan bobot sub kriteria
harga_per_alat_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'harga_alat').set_index('SK Harga Per Alat')

jumlah_perbaris_HPA = harga_per_alat_comparison_matrix.dot(bobot_harga_per_alat)
jumlah_perbaris_HPA['Jumlah Perbaris'] = jumlah_perbaris_HPA.pop('Bobot')
jumlah_perbaris_HPA
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3cc268730ee8> in <cell line: 2>()
#       1 # Mencari jumlah perbaris sub kriteria dari perkalian matriks tabel perbandingan dengan bobot sub kriteria
# ----> 2 harga_per_alat_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'harga_alat').set_index('SK Harga Per Alat')
#       3
#       4 jumlah_perbaris_HPA = harga_per_alat_comparison_matrix.dot(bobot_harga_per_alat)
#       5 jumlah_perbaris_HPA['Jumlah Perbaris'] = jumlah_perbaris_HPA.pop('Bobot')
#
# NameError: name 'pd' is not defined

# %%
#pembagian jumlah perbaris dengan bobot setiap sub kriteria
Hasil_harga_per_alat = jumlah_perbaris_HPA.copy()
for x in ['Jumlah Perbaris']:
    Hasil_harga_per_alat[x] = Hasil_harga_per_alat[x] / bobot_harga_per_alat['Bobot']
Emaks_harga_per_alat = Hasil_harga_per_alat[x].sum() / harga_per_alat_comparison['SK Harga Per Alat'].count()
Emaks_harga_per_alat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3953fa29d838> in <cell line: 2>()
#       1 #pembagian jumlah perbaris dengan bobot setiap sub kriteria
# ----> 2 Hasil_harga_per_alat = jumlah_perbaris_HPA.copy()
#       3 for x in ['Jumlah Perbaris']:
#       4     Hasil_harga_per_alat[x] = Hasil_harga_per_alat[x] / bobot_harga_per_alat['Bobot']
#       5 Emaks_harga_per_alat = Hasil_harga_per_alat[x].sum() / harga_per_alat_comparison['SK Harga Per Alat'].count()
#
# NameError: name 'jumlah_perbaris_HPA' is not defined

# %%
#STEP 6.4.2 Indeks konsistensi sub kriteria Harga_Per_Alat

CI_harga_per_alat = (Emaks_harga_per_alat - harga_per_alat_comparison['SK Harga Per Alat'].count()) / (harga_per_alat_comparison['SK Harga Per Alat'].count()-1)
CI_harga_per_alat
# Out:
# 0.004438666461171081

# %%
#STEP 6.4.3 Rasio konsistensi sub kriteria Harga_Per_Alat

IR_harga_per_alat = IR.get(harga_per_alat_comparison['SK Harga Per Alat'].count(), None)
if IR_harga_per_alat is not None:
    IR_harga_per_alat
else:
    0
CR_harga_per_alat = CI_harga_per_alat / IR_harga_per_alat
CR_harga_per_alat
# Out:
# 0.007652873208915658

# %%
#STEP 6.4.4 Memeriksa konsistensi data sub kriteria Harga_Per_Alat

if CR_harga_per_alat < 0.1:
    print("Data sudah konsisten")
else:
    print("Data belum konsisten, lakukan penilaian ulang")
# Out:
# Data sudah konsisten

# %%
#STEP 6.4.5 Hasil rasio konsistensi sub kriteria Harga_Per_Alat
# Nilai konsistensi data sub kriteria Harga_Per_Alat adalah 0,008 (CR)

# %% [markdown]
# ### 6.5 Rasio Konsistensi Data Sub Kriteria Waktu_Penyelesaian

# %%
#STEP 6.5.1 EMaks / λmaks sub kriteria Waktu_Penyelesaian

# Mencari jumlah perbaris sub kriteria dari perkalian matriks tabel perbandingan dengan bobot sub kriteria
waktu_penyelesaian_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'waktu_penyelesaian').set_index('SK Waktu Penyelesaian')

jumlah_perbaris_WP = waktu_penyelesaian_comparison_matrix.dot(bobot_waktu_penyelesaian)
jumlah_perbaris_WP['Jumlah Perbaris'] = jumlah_perbaris_WP.pop('Bobot')
jumlah_perbaris_WP
# Out:
#                        Jumlah Perbaris
# SK Waktu Penyelesaian
# Terlambat                     0.184634
# Tepat Waktu                   1.392040
# Sangat Cepat                  1.465774

# %%
#pembagian jumlah perbaris dengan bobot setiap sub kriteria
Hasil_waktu_penyelesaian = jumlah_perbaris_WP.copy()
for x in ['Jumlah Perbaris']:
    Hasil_waktu_penyelesaian[x] = Hasil_waktu_penyelesaian[x] / bobot_waktu_penyelesaian['Bobot']
Emaks_waktu_penyelesaian = Hasil_waktu_penyelesaian[x].sum() / waktu_penyelesaian_comparison['SK Waktu Penyelesaian'].count()
Emaks_waktu_penyelesaian
# Out:
# 3.0318496747038624

# %%
#STEP 6.5.2 Indeks konsistensi sub kriteria Waktu_Penyelesaian

CI_waktu_penyelesaian = (Emaks_waktu_penyelesaian - waktu_penyelesaian_comparison['SK Waktu Penyelesaian'].count()) / (waktu_penyelesaian_comparison['SK Waktu Penyelesaian'].count()-1)
CI_waktu_penyelesaian
# Out:
# 0.015924837351931176

# %%
#STEP 6.5.3 Rasio konsistensi sub kriteria Waktu_Penyelesaian

IR_waktu_penyelesaian = IR.get(waktu_penyelesaian_comparison['SK Waktu Penyelesaian'].count(), None)
if IR_waktu_penyelesaian is not None:
    IR_waktu_penyelesaian
else:
    0
CR_waktu_penyelesaian = CI_waktu_penyelesaian / IR_waktu_penyelesaian
CR_waktu_penyelesaian
# Out:
# 0.02745661612401927

# %%
#STEP 6.5.4 Memeriksa konsistensi data sub kriteria Waktu_Penyelesaian

if CR_waktu_penyelesaian < 0.1:
    print("Data sudah konsisten")
else:
    print("Data belum konsisten, lakukan penilaian ulang")
# Out:
# Data sudah konsisten

# %%
#STEP 6.5.5 Hasil rasio konsistensi sub kriteria Waktu_Penyelesaian
# Nilai konsistensi data sub kriteria Waktu_Penyelesaian adalah 0,027 (CR)

# %% [markdown]
# ### 6.6 Rasio Konsistensi Data Sub Kriteria Ulasan_Pelanggan

# %%
#STEP 6.6.1 EMaks / λmaks sub kriteria Ulasan_Pelanggan

# Mencari jumlah perbaris sub kriteria dari perkalian matriks tabel perbandingan dengan bobot sub kriteria
ulasan_pelanggan_comparison_matrix = pd.read_excel('/content/drive/MyDrive/Data_PT_XYZ/AHP_PT_XYZ.xlsx', sheet_name= 'ulasan_pelanggan').set_index('SK Ulasan Pelanggan')

jumlah_perbaris_UP = ulasan_pelanggan_comparison_matrix.dot(bobot_ulasan_pelanggan)
jumlah_perbaris_UP['Jumlah Perbaris'] = jumlah_perbaris_UP.pop('Bobot')
jumlah_perbaris_UP
# Out:
#                      Jumlah Perbaris
# SK Ulasan Pelanggan
# Kurang Puas                 0.186294
# Puas                        1.144421
# Sangat Puas                 1.677925

# %%
#pembagian jumlah perbaris dengan bobot setiap sub kriteria
Hasil_ulasan_pelanggan = jumlah_perbaris_UP.copy()
for x in ['Jumlah Perbaris']:
    Hasil_ulasan_pelanggan[x] = Hasil_ulasan_pelanggan[x] / bobot_ulasan_pelanggan['Bobot']
Emaks_ulasan_pelanggan = Hasil_ulasan_pelanggan[x].sum() / ulasan_pelanggan_comparison['SK Ulasan Pelanggan'].count()
Emaks_ulasan_pelanggan
# Out:
# 3.006297787013588

# %%
#STEP 6.6.2 Indeks konsistensi sub kriteria Ulasan_Pelanggan

CI_ulasan_pelanggan = (Emaks_ulasan_pelanggan - ulasan_pelanggan_comparison['SK Ulasan Pelanggan'].count()) / (ulasan_pelanggan_comparison['SK Ulasan Pelanggan'].count()-1)
CI_ulasan_pelanggan
# Out:
# 0.003148893506794037

# %%
#STEP 6.6.3 Rasio konsistensi sub kriteria Ulasan_Pelanggan

IR_ulasan_pelanggan = IR.get(ulasan_pelanggan_comparison['SK Ulasan Pelanggan'].count(), None)
if IR_ulasan_pelanggan is not None:
    IR_ulasan_pelanggan
else:
    0
CR_ulasan_pelanggan = CI_ulasan_pelanggan / IR_ulasan_pelanggan
CR_ulasan_pelanggan
# Out:
# 0.005429126735851789

# %%
#STEP 6.6.4 Memeriksa konsistensi data sub kriteria Ulasan_Pelanggan

if CR_ulasan_pelanggan < 0.1:
    print("Data sudah konsisten")
else:
    print("Data belum konsisten, lakukan penilaian ulang")
# Out:
# Data sudah konsisten

# %%
#STEP 6.6.5 Hasil rasio konsistensi sub kriteria Ulasan_Pelanggan
# Nilai konsistensi data sub kriteria Ulasan_Pelanggan adalah 0,005 (CR)

# %% [markdown]
# ## Step 7 : Perankingan

# %%
#STEP 7.1 Rekap Bobot Kriteria dan Sub Kriteria

#Bobot setiap kriteria
bobot_JP = bobot_kriteria.iloc[0, 0]
bobot_JAM = bobot_kriteria.iloc[1, 0]
bobot_HPA = bobot_kriteria.iloc[2, 0]
bobot_WP = bobot_kriteria.iloc[3, 0]
bobot_UP = bobot_kriteria.iloc[4, 0]

#Bobot Sub Kriteria Jumlah_Pelanggan
bobot_dibawah_3 = bobot_jumlah_pelanggan.iloc[0, 0]
bobot_antara_3_5 = bobot_jumlah_pelanggan.iloc[1, 0]
bobot_diatas_5 = bobot_jumlah_pelanggan.iloc[2, 0]

#Bobot Sub Kriteria Jumlah_Alat_Masuk
bobot_dibawah_50 = bobot_jumlah_alat_masuk.iloc[0, 0]
bobot_antara_50_100 = bobot_jumlah_alat_masuk.iloc[1, 0]
bobot_diatas_100 = bobot_jumlah_alat_masuk.iloc[2, 0]

#Bobot Sub Kriteria Harga_Per_Alat
bobot_dibawah_200000 = bobot_harga_per_alat.iloc[0, 0]
bobot_antara_200000_350000 = bobot_harga_per_alat.iloc[1, 0]
bobot_diatas_350000 = bobot_harga_per_alat.iloc[2, 0]

#Bobot Sub Kriteria Waktu_Penyelesaian
bobot_terlambat = bobot_waktu_penyelesaian.iloc[0, 0]
bobot_tepat_waktu = bobot_waktu_penyelesaian.iloc[1, 0]
bobot_sangat_cepat = bobot_waktu_penyelesaian.iloc[2, 0]

#Bobot Sub Kriteria Ulasan_Pelanggan
bobot_kurang_puas = bobot_ulasan_pelanggan.iloc[0, 0]
bobot_puas = bobot_ulasan_pelanggan.iloc[1, 0]
bobot_sangat_puas = bobot_ulasan_pelanggan.iloc[2, 0]

# %%
#STEP 7.2 Input data 1 periode

#Input Data
input_data = pd.read_excel('/content/drive/MyDrive/555_RESEARCH_MAHASISWA/00_2023_IVAN_SIREGAR/AHP/AHP_PT_XYZ.xlsx', sheet_name= 'input_data')
input_data
# Out:
#                 Alat  Jumlah Pelanggan  Jumlah Alat Masuk  Harga Per Alat  \
# 0         Plug Gauge                 6                 99          280000
# 1  Thread Plug Gauge                 3                 49          330000
# 2  Thread Ring Gauge                 4                 51          350000
# 3         Instrument                 2                 20          150000
#
#   Waktu Penyelesaian Ulasan Pelanggan
# 0       Sangat Cepat      Sangat Puas
# 1        Tepat Waktu             Puas
# 2        Tepat Waktu             Puas
# 3       Sangat Cepat             Puas

# %%
#STEP 7.3 Hitung bobot alternatif

bobot_alat_per_kriteria = input_data.copy()

for kriteria in ['Jumlah Pelanggan', 'Jumlah Alat Masuk', 'Harga Per Alat', 'Waktu Penyelesaian', 'Ulasan Pelanggan']:
    if kriteria == 'Jumlah Pelanggan':
        bobot_alat_per_kriteria['Jumlah Pelanggan'] = np.where(bobot_alat_per_kriteria[kriteria] < 3, bobot_JP * bobot_dibawah_3,
                                                         np.where(bobot_alat_per_kriteria[kriteria] > 5, bobot_JP * bobot_diatas_5,
                                                         bobot_JP * bobot_antara_3_5))
    elif kriteria == 'Jumlah Alat Masuk':
        bobot_alat_per_kriteria['Jumlah Alat Masuk'] = np.where(bobot_alat_per_kriteria[kriteria] < 50, bobot_JAM * bobot_dibawah_50,
                                                         np.where(bobot_alat_per_kriteria[kriteria] > 100, bobot_JAM * bobot_diatas_100,
                                                         bobot_JAM * bobot_antara_50_100))
    elif kriteria == 'Harga Per Alat':
        bobot_alat_per_kriteria['Harga Per Alat'] = np.where(bobot_alat_per_kriteria[kriteria] < 200000, bobot_HPA * bobot_dibawah_200000,
                                                         np.where(bobot_alat_per_kriteria[kriteria] > 350000, bobot_HPA * bobot_diatas_350000,
                                                         bobot_HPA * bobot_antara_200000_350000))
    elif kriteria == 'Waktu Penyelesaian':
        bobot_alat_per_kriteria['Waktu Penyelesaian'] = np.where(bobot_alat_per_kriteria[kriteria] == 'Terlambat', bobot_WP * bobot_terlambat,
                                                         np.where(bobot_alat_per_kriteria[kriteria] == 'Tepat Waktu', bobot_WP * bobot_tepat_waktu,
                                                         bobot_WP * bobot_sangat_cepat))
    elif kriteria == 'Ulasan Pelanggan':
        bobot_alat_per_kriteria['Ulasan Pelanggan'] = np.where(bobot_alat_per_kriteria[kriteria] == 'Kurang Puas', bobot_UP * bobot_kurang_puas,
                                                         np.where(bobot_alat_per_kriteria[kriteria] == 'Puas', bobot_UP * bobot_puas,
                                                         bobot_UP * bobot_sangat_puas))
bobot_alat_per_kriteria
# Out:
#                 Alat  Jumlah Pelanggan  Jumlah Alat Masuk  Harga Per Alat  \
# 0         Plug Gauge          0.028372           0.236490        0.049790
# 1  Thread Plug Gauge          0.022182           0.054839        0.049790
# 2  Thread Ring Gauge          0.022182           0.236490        0.049790
# 3         Instrument          0.004884           0.054839        0.009232
#
#    Waktu Penyelesaian  Ulasan Pelanggan
# 0            0.118487          0.061546
# 1            0.112374          0.042017
# 2            0.112374          0.042017
# 3            0.118487          0.042017

# %%
#STEP XXXXX

Bobot_Plug = (bobot_alat_per_kriteria['Jumlah Pelanggan'][0] + bobot_alat_per_kriteria['Jumlah Alat Masuk'][0] + bobot_alat_per_kriteria['Harga Per Alat'][0] + bobot_alat_per_kriteria['Waktu Penyelesaian'][0] + bobot_alat_per_kriteria['Ulasan Pelanggan'][0])
Bobot_Thread_Plug = (bobot_alat_per_kriteria['Jumlah Pelanggan'][1] + bobot_alat_per_kriteria['Jumlah Alat Masuk'][1] + bobot_alat_per_kriteria['Harga Per Alat'][1] + bobot_alat_per_kriteria['Waktu Penyelesaian'][1] + bobot_alat_per_kriteria['Ulasan Pelanggan'][1])
Bobot_Thread_Ring = (bobot_alat_per_kriteria['Jumlah Pelanggan'][2] + bobot_alat_per_kriteria['Jumlah Alat Masuk'][2] + bobot_alat_per_kriteria['Harga Per Alat'][2] + bobot_alat_per_kriteria['Waktu Penyelesaian'][2] + bobot_alat_per_kriteria['Ulasan Pelanggan'][2])
Bobot_Instrument = (bobot_alat_per_kriteria['Jumlah Pelanggan'][3] + bobot_alat_per_kriteria['Jumlah Alat Masuk'][3] + bobot_alat_per_kriteria['Harga Per Alat'][3] + bobot_alat_per_kriteria['Waktu Penyelesaian'][3] + bobot_alat_per_kriteria['Ulasan Pelanggan'][3])
Bobot_Perankingan = {'Alat' : ['Plug Gauge','Thread Plug Gauge','Thread Ring Gauge','Instrument'],
                     'Bobot' : [Bobot_Plug, Bobot_Thread_Plug, Bobot_Thread_Ring, Bobot_Instrument]}
Perankingan = pd.DataFrame(Bobot_Perankingan)
Perankingan
# Out:
#                 Alat     Bobot
# 0         Plug Gauge  0.494685
# 1  Thread Plug Gauge  0.281201
# 2  Thread Ring Gauge  0.462852
# 3         Instrument  0.229459

# %%
#STEP XXXXX

# Menyaring DataFrame berdasarkan kolom 'A' dari yang besar ke yang kecil
Ranking = Perankingan.sort_values(by='Bobot', ascending=False)
# Menyusun ulang indeks dari 1 hingga terakhir
Ranking.reset_index(drop=True, inplace=True)
# Menambahkan kolom baru 'peringkat' berdasarkan nilai kolom 'A'
Ranking['Peringkat'] = Ranking['Bobot'].rank(ascending=False, method='min')
Ranking
# Out:
#                 Alat     Bobot  Peringkat
# 0         Plug Gauge  0.494685        1.0
# 1  Thread Ring Gauge  0.462852        2.0
# 2  Thread Plug Gauge  0.281201        3.0
# 3         Instrument  0.229459        4.0

# %%
#STEP XXXXXX

plt.figure(figsize=(8,4))
plt.bar('Alat', 'Bobot', color = ['dimgray','navy','purple','maroon'], data=Ranking)
plt.title('Perbandingan Alternatif Setiap Alat')
plt.xlabel('Alat')
plt.ylabel('Bobot Alternatif')
plt.show()

# %%
#STEP 7.4 Hasil / Keputusan Akhir

#Hasil akhir di atas menunjukkan bahwa penjualan terbaik dari keempat alat adalah :
#
#1. Plug gauge
#2. Thread ring gauge
#3. Thread plug gauge
#4. Instrument
